# %%
#from requests import get
import requests
#from requests.exceptions import RequestException
#from contextlib import closing
from bs4 import BeautifulSoup
import re

# %%
protocol = 'https://'
location = 'www.kroger.com'
resource = '/products/api/products/details'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36',
          'Referer': 'https://www.kroger.com/search?query=chicken&searchType=natural'}

template = '{}{}{}'
url = template.format(protocol, location, resource)

url
# Out:
# 'https://www.kroger.com/products/api/products/details'

# %%
resp = requests.post(url, headers=headers)

# %%
if resp.status_code != 200:
    print('Error retieving request from', url)
# Out:
# Error retieving request from https://www.kroger.com/products/api/products/details

# %%
#resp.headers

# %%
#resp.text

# %%
#resp.content

# %%
html = BeautifulSoup(resp.content, 'html.parser')
print(html.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en-us">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,shrink-to-fit=no" name="viewport"/>
#   <meta content="mLDjWodVihPJXvMAL0-8hcbuNludulWFtLJ5FFFMbyk" name="google-site-verification"/>
#   <meta content="app-id=403901186" name="apple-itunes-app"/>
#   <meta content="app-id=com.kroger.mobile" name="google-play-app"/>
#   <meta content="#0067b1" name="theme-color"/>
#   <script data-dtconfig="rid=RID_2017652271|rpid=987029762|domain=kroger.com|reportUrl=/rb_7571065c-f052-471e-a3d7-f99d529548bb|app=81222ad3b2deb1ef|ssc=1|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|featureHash=ICA27SVdfghjqrtx|md=8=cpid|lastModification=1551730433430|dtVersion=10161190228170440|tp=500,50,0,1|rdnt=1|uxrgce=1|agentUri=/ruxitagentjs_ICA27SVdfghjqrtx_10161190228170440.js" src="/ruxitagentjs_ICA27SVdfghjqrtx_10161190228170440.js" type="text/javascript">
#   </script>
# ...

# %%
html.find_all(string=re.compile("Price"))
# Out:
# []

# %%
for i, div in enumerate(html.find_all("a")):
        print(i, div.get('class'))
# Out:
# 0 None
# 1 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 2 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 3 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 4 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 5 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 6 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 7 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 8 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 9 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 10 ['Color', 'Link']
# 11 ['ListItem-Link', 'ListItem-Link-Dropdown']
# 12 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 13 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 14 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# 15 ['Color', 'ListItem-Link', 'ListItem-Link-Navigation', 'Link']
# ...
