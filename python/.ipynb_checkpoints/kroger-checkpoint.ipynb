# %%
#from requests import get
import requests
#from requests.exceptions import RequestException
#from contextlib import closing
from bs4 import BeautifulSoup

# %%
protocol = 'https://'
location = 'www.kroger.com'
resource = '/search?query=chicken breast'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

template = '{}{}{}'
url = template.format(protocol, location, resource)

url
# Out:
# 'https://www.kroger.com/search?query=chicken breast'

# %%
resp = requests.get(url, headers=headers)

# %%
if resp.status_code != 200:
    print('Error retieving request from', url)

# %%
resp.headers
# Out:
# {'Server': 'nginx', 'Content-Type': 'text/html; charset=utf-8', 'Vary': 'Accept-Encoding', 'X-Oneagent-Js-Injection': 'true', 'X-Ruxit-Js-Agent': 'true', 'X-Vcap-Request-Id': 'da0253cc-79e5-428d-6acb-d166f6a9a6de', 'Content-Encoding': 'gzip', 'X-Akamai-Transformed': '9 9652 0 pmb=mTOE,4', 'Expires': 'Mon, 18 Feb 2019 19:57:32 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Mon, 18 Feb 2019 19:57:32 GMT', 'Content-Length': '8849', 'Connection': 'keep-alive', 'Set-Cookie': 'dtCookie=4$1B91E1C97BD070C44AF03A38628C0BAE; Path=/; Domain=.kroger.com; secure, ak_bmsc=305C8C3199EEE924526D306CE44241BB48F67506B95000002C0E6B5C3692E962~pl+3oZIPXZo8iSeZZh1049R4HouVHNpj7K0m+6XPD+6bmH/xNROnDqRu/r+WH+wejiE6nXbYFdlMzFRzBy9TFE5JK/rbPreXBJrlW4PmeCh1y59HAAc2UcUjm37Gj9rr2dzxC+7FCeoUdWr+OygnLxDbA/JX6GzBKRhv7xHIkhrnBRlBwKCuoAKl2VpPLGwuq49HEY/slzgva4YnJb9IqrdzovYK6zXp1NbnRmlsp+O+c=; expires=Mon, 18 Feb 2019 21:57:32 GMT; max-age=7200; path=/; domain=.kroger.com; HttpOnly, akaalb_KT_Digital_BannerSites=~op=KT_Digital_BannerSites_Legacy:kcvg|~rv=43~m=kcvg:0|~os=49d9e32c4b6129ccff2e66f9d0390271~id=24ef4a91d505b66703b39f6ba499dc18; path=/;; Secure; HttpOnly, _abck=FEA86109083B4B17EACF8A3E5F7D35FF48F67506B95000002C0E6B5CA10DD82F~-1~RT//Trj089UNEv0iS2zXtSFdgyd68S8SCQJEJEvamMg=~-1~-1; expires=Tue, 18 Feb 2020 19:57:32 GMT; max-age=31536000; path=/; domain=.kroger.com, bm_mi=A6E6DBD9DBC9EB2D9A083B298CF4BCC2~02jeT6iz0+xh+/LhEVYbx2HRftDwQd+MWiyeQAitggODOQPImVQi1B1mQKEfXZyuIEwe+KmPvko3r/b6XxyIs/Udvzwjm8UKD3tjL7BRMU8Z63e4VYy8IbgyqpzT95SYfYEDp3Eu24vjXz/kvzQF38bYPOwg34rALPmzmVOJ4Y4SXjc9aUa3wJIN89fv+fwxWH0eyXfpvRPza+8GeAVpGk3j1h9la37UStJZ3tHyRJQ=; Domain=.kroger.com; Path=/; Max-Age=0; HttpOnly, bm_sz=D03D31DC8C35E4AA1F7BD2AD5F1E81BB~YAAQBnX2SCsHSLJoAQAAjl4vAgL7K49S3YGCKSbJPy+sQJ3sF8uoj40rRYZm2BmWCYEhmZo0uha1h9qv4vIYPFaUqraJYPQq812LyBcmMeytTJw6LZ9fPM9aSR8kn5PWUaTHa9qpPfibqAx9ZxxyLqkJ194BHvxdqNL5GoR5tZ3MSS4EhnLP714kvT+1xOM6; Domain=.kroger.com; Path=/; Expires=Mon, 18 Feb 2019 23:57:32 GMT; Max-Age=14400; HttpOnly', 'X-KT-COD-DC2': 'kcvg', 'X-KT-ACR-LMA-CT': 'true', 'Strict-Transport-Security': 'max-age=31536000 ; includeSubDomains'}

# %%
resp.text
# Out:
# '<!doctype html>\n<html lang="en-us">\n<head>\n  <meta charset="utf-8" />\n  <meta name="viewport" content="width=device-width,initial-scale=1,shrink-to-fit=no" />\n  <meta name="google-site-verification" content="mLDjWodVihPJXvMAL0-8hcbuNludulWFtLJ5FFFMbyk" />\n      <meta name="apple-itunes-app" content="app-id=403901186" />\n      <meta name="google-play-app" content="app-id=com.kroger.mobile" />\n      <meta name="theme-color" content="#0067b1" />\n      <script type="text/javascript" src="/ruxitagentjs_ICA27SVdfghjqrtx_10159190121190724.js" data-dtconfig="rid=RID_-1615648870|rpid=1396694366|domain=kroger.com|reportUrl=/rb_7571065c-f052-471e-a3d7-f99d529548bb|app=81222ad3b2deb1ef|ssc=1|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|featureHash=ICA27SVdfghjqrtx|md=8=cpid|srad=1|lastModification=1550519788242|dtVersion=10159190121190724|tp=500,50,0,1|rdnt=1|uxrgce=1|agentUri=/ruxitagentjs_ICA27SVdfghjqrtx_10159190121190724.js"></script><link rel="search" type="application/opensearchdescription+xml" href="/osd.xml" title="Kroger" />\n      <link rel="manifest" href="/site.webmanifest" />\n      <link rel="apple-touch-icon" href="/apple-touch-icon.png" />\n      <link rel="mask-icon" href="/safari-pinned-tab.svg" />\n  <title data-react-helmet="true">Kroger</title>\n  \n  \n  \n  <link rel=\'stylesheet\' href=\'/sa/vendors~main.1680df321e.css\' />\n<link rel=\'stylesheet\' href=\'/sa/kroger-header.ea4366e033.css\' />\n<link rel=\'stylesheet\' href=\'/sa/kroger-search-page.628e0c27fb.css\' />\n<link rel=\'stylesheet\' href=\'/sa/containers/SearchGrids.1804f00b92.css\' />\n<link rel=\'stylesheet\' href=\'/sa/kroger-footer.a8decfa35f.css\' />\n  <link rel="stylesheet" href="/sa/kds-utils.css">\n  \n  <script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}gtag(\'js\',\n    new Date());gtag(\'config\', \'UA-132319230-13\', { \'optimize_id\': \'GTM-NKV8DT6\'})</script>\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-132319230-13"></script>\n  \n  \n  <script data-qa-dtm-header-script="true" src="https://assets.adobedtm.com/5b62a4686de413bb78d18e54ea62461ac9cf5893/satelliteLib-0b077667ec685cd85f99d92cf0324b7ba35326f5.js"></script>\n  <style type="text/css" id="kroger-ssr-jss-styles">\n    \n  </style>\n<script>bazadebezolkohpepadr="113307257"</script><script type="text/javascript" src="https://www.kroger.com/akam/10/6c0eca1" defer></script></head>\n<body >\n  <div id="root"><div data-reactroot=""><div class="Page"><a id="skip-link" href="#content">Skip to content</a><div class="Page-top-fixed"><div></div></div><div class="Page-top-block"><div><div></div></div><div id="QuickLinksContainer" class="UpdatedQuickLinksContainer"><div id="QuickLinksTabsToggledContainer"></div><div id="LinkListContainer-QuickLinks" class="DesktopLinkList LinkListContainer"></div></div><div class="KrogerHeaderContainer"><div class="KrogerHeader"><div class="KrogerHeader-Item KrogerHeader-Logo"><div class="KrogerHeader-Logo--inner"><a class="Color Link"><div class="KImage-container" style="width:100%;height:100%"><img class="Image" src="" srcSet="" style="height:100%;width:initial;max-width:100%;position:relative;top:inherit;left:inherit"/></div></a></div></div><div class="KrogerHeader-Item KrogerHeader-Search"><div class="SearchBarHeader"><form action="/search" role="search" autoComplete="off"><div class="searchbar-box"><span><span class="searchHeaderInput Input Input--text"><input type="text" aria-invalid="false" aria-label="Search" aria-describedby="Input-searchbar-described" id="searchbar" name="query" placeholder="What are you looking for today?" value="" class="Input-input Input-input--hasIcon input searchInput" title="Search"/></span><span id="Input-searchbar-described" class="u-screenReader" aria-hidden="true"></span></span><button class="searchbar-searchButton" aria-label="Search"><span data-text="white" data-icon="white" class="Color"><span data-kind="search" class="searchbar-searchIcon Icon Colo ...

# %%
resp.content
# Out:
# b'<!doctype html>\n<html lang="en-us">\n<head>\n  <meta charset="utf-8" />\n  <meta name="viewport" content="width=device-width,initial-scale=1,shrink-to-fit=no" />\n  <meta name="google-site-verification" content="mLDjWodVihPJXvMAL0-8hcbuNludulWFtLJ5FFFMbyk" />\n      <meta name="apple-itunes-app" content="app-id=403901186" />\n      <meta name="google-play-app" content="app-id=com.kroger.mobile" />\n      <meta name="theme-color" content="#0067b1" />\n      <script type="text/javascript" src="/ruxitagentjs_ICA27SVdfghjqrtx_10159190121190724.js" data-dtconfig="rid=RID_-1615648870|rpid=1396694366|domain=kroger.com|reportUrl=/rb_7571065c-f052-471e-a3d7-f99d529548bb|app=81222ad3b2deb1ef|ssc=1|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|featureHash=ICA27SVdfghjqrtx|md=8=cpid|srad=1|lastModification=1550519788242|dtVersion=10159190121190724|tp=500,50,0,1|rdnt=1|uxrgce=1|agentUri=/ruxitagentjs_ICA27SVdfghjqrtx_10159190121190724.js"></script><link rel="search" type="application/opensearchdescription+xml" href="/osd.xml" title="Kroger" />\n      <link rel="manifest" href="/site.webmanifest" />\n      <link rel="apple-touch-icon" href="/apple-touch-icon.png" />\n      <link rel="mask-icon" href="/safari-pinned-tab.svg" />\n  <title data-react-helmet="true">Kroger</title>\n  \n  \n  \n  <link rel=\'stylesheet\' href=\'/sa/vendors~main.1680df321e.css\' />\n<link rel=\'stylesheet\' href=\'/sa/kroger-header.ea4366e033.css\' />\n<link rel=\'stylesheet\' href=\'/sa/kroger-search-page.628e0c27fb.css\' />\n<link rel=\'stylesheet\' href=\'/sa/containers/SearchGrids.1804f00b92.css\' />\n<link rel=\'stylesheet\' href=\'/sa/kroger-footer.a8decfa35f.css\' />\n  <link rel="stylesheet" href="/sa/kds-utils.css">\n  \n  <script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}gtag(\'js\',\n    new Date());gtag(\'config\', \'UA-132319230-13\', { \'optimize_id\': \'GTM-NKV8DT6\'})</script>\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-132319230-13"></script>\n  \n  \n  <script data-qa-dtm-header-script="true" src="https://assets.adobedtm.com/5b62a4686de413bb78d18e54ea62461ac9cf5893/satelliteLib-0b077667ec685cd85f99d92cf0324b7ba35326f5.js"></script>\n  <style type="text/css" id="kroger-ssr-jss-styles">\n    \n  </style>\n<script>bazadebezolkohpepadr="113307257"</script><script type="text/javascript" src="https://www.kroger.com/akam/10/6c0eca1" defer></script></head>\n<body >\n  <div id="root"><div data-reactroot=""><div class="Page"><a id="skip-link" href="#content">Skip to content</a><div class="Page-top-fixed"><div></div></div><div class="Page-top-block"><div><div></div></div><div id="QuickLinksContainer" class="UpdatedQuickLinksContainer"><div id="QuickLinksTabsToggledContainer"></div><div id="LinkListContainer-QuickLinks" class="DesktopLinkList LinkListContainer"></div></div><div class="KrogerHeaderContainer"><div class="KrogerHeader"><div class="KrogerHeader-Item KrogerHeader-Logo"><div class="KrogerHeader-Logo--inner"><a class="Color Link"><div class="KImage-container" style="width:100%;height:100%"><img class="Image" src="" srcSet="" style="height:100%;width:initial;max-width:100%;position:relative;top:inherit;left:inherit"/></div></a></div></div><div class="KrogerHeader-Item KrogerHeader-Search"><div class="SearchBarHeader"><form action="/search" role="search" autoComplete="off"><div class="searchbar-box"><span><span class="searchHeaderInput Input Input--text"><input type="text" aria-invalid="false" aria-label="Search" aria-describedby="Input-searchbar-described" id="searchbar" name="query" placeholder="What are you looking for today?" value="" class="Input-input Input-input--hasIcon input searchInput" title="Search"/></span><span id="Input-searchbar-described" class="u-screenReader" aria-hidden="true"></span></span><button class="searchbar-searchButton" aria-label="Search"><span data-text="white" data-icon="white" class="Color"><span data-kind="search" class="searchbar-searchIcon Icon Col ...

# %%
html = BeautifulSoup(resp.content, 'html.parser')

# %%
for i, div in enumerate(html.select('span')):
        print(i, div.text)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6 Find a Store to Shop!
# 7
# 8 Find a Store to Shop!
# 9
# 10
# 11 Menu
# 12
# 13
# 14
# 15
# 16
# 17
# 18 $0.00
# 19
# 20 All Contents © Copyright 2019 The Kroger Co. All Rights ReservedIf you are using a screen reader and having difficulty with this website please call 1-800-576-4377.
# 21 All Contents © Copyright 2019 The Kroger Co.
# 22 © Copyright 2019
# 23 All Rights Reserved
# 24 If you are using a screen reader and having difficulty with this website please call 1-800-576-4377.
# 25  |
# 26  |
# 27 To create and edit your shopping list, sign in to your account.
# 28 Sign In
# 29 Don’t have an account?
# 30 Create an Account
