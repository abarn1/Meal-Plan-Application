# %%
import pandas as pd
import requests as req
import numpy as np

# %%
nutrition = pd.read_csv('Nutrients.csv')
nutrition
# Out:
#            NDB_No  Nutrient_Code                       Nutrient_name  \
# 0        45127487            203                             Protein
# 1        45127487            204                   Total lipid (fat)
# 2        45127487            205         Carbohydrate, by difference
# 3        45127487            207                                 Ash
# 4        45127487            255                               Water
# 5        45127487            269                       Sugars, total
# 6        45127487            291                Fiber, total dietary
# 7        45127487            295                      Fiber, soluble
# 8        45127487            297                    Fiber, insoluble
# 9        45127487            301                         Calcium, Ca
# 10       45127487            303                            Iron, Fe
# 11       45127487            304                       Magnesium, Mg
# 12       45127487            305                       Phosphorus, P
# ...

# %%
table = pd.pivot_table(nutrition, columns = ['Nutrient_Code'], index = ['NDB_No'], values = ['Output_value'])
table
# Out:
#               Output_value                                               ...  \
# Nutrient_Code          203    204     205 207    208 209 211 212 213 221 ...
# NDB_No                                                                   ...
# 45001524              2.50   6.25   35.00 NaN  200.0 NaN NaN NaN NaN NaN ...
# 45001528              0.00   0.00   43.24 NaN  162.0 NaN NaN NaN NaN NaN ...
# 45001529              0.00   0.00   41.18 NaN  176.0 NaN NaN NaN NaN NaN ...
# 45001530              0.00   0.00   34.29 NaN  143.0 NaN NaN NaN NaN NaN ...
# 45001531              0.00   0.00   45.95 NaN  189.0 NaN NaN NaN NaN NaN ...
# 45001532              0.00   0.00   48.65 NaN  189.0 NaN NaN NaN NaN NaN ...
# 45001533              0.00   0.00   34.29 NaN  143.0 NaN NaN NaN NaN NaN ...
# 45001534              0.00   0.00   36.11 NaN  139.0 NaN NaN NaN NaN NaN ...
# 45001535              0.00   0.00   20.00 NaN  100.0 NaN NaN NaN NaN NaN ...
# ...
